# %%
# %pip install -q -r requirements.txt
# Out:
# ERROR: Could not find a version that satisfies the requirement langchain-chromadb (from versions: none)
# ERROR: No matching distribution found for langchain-chromadb

# %%
from langchain_community.document_loaders import DirectoryLoader, UnstructuredFileLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_22004\3510866223.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader, UnstructuredFileLoader

# %%
import nltk
nltk.download("punkt_tab")
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %% [markdown]
# To do:
#
# Install Poppler
# Install Tesseract

# %%
# configuration
docs_dir_path = "./6_RAG SYSTEMS/docs_dir"
vector_db_path = "./6_RAG SYSTEMS/vector_db"
collection_name  = "document_collection"

# %%
# loading the embedding model
embedding = HuggingFaceEmbeddings()

# %%
# directory loader
loader = DirectoryLoader(
    path=docs_dir_path,
    glob="./*.pdf",
    loader_cls=UnstructuredFileLoader
)

# single file can also be loaded with UnstructuredFileLoader

# %%
documents = loader.load()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 documents = loader.load()
#
# File d:\anaconda\Lib\site-packages\langchain_community\document_loaders\directory.py:117, in DirectoryLoader.load(self)
#     115 def load(self) -> List[Document]:
#     116     """Load documents."""
# --> 117     return list(self.lazy_load())
#
# File d:\anaconda\Lib\site-packages\langchain_community\document_loaders\directory.py:123, in DirectoryLoader.lazy_load(self)
#     121 p = Path(self.path)
#     122 if not p.exists():
# --> 123     raise FileNotFoundError(f"Directory not found: '{self.path}'")
#     124 if not p.is_dir():
#     125     raise ValueError(f"Expected directory, got file: '{self.path}'")
#
# FileNotFoundError: Directory not found: './6_RAG SYSTEMS/docs_dir'
