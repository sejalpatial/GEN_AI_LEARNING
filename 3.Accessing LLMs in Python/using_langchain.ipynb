# %% [markdown]
# Langchain - LangChain is a framework that lets developers use different LLMs through a common interface and build more complex AI applications.
# It provides a unified interface for building LLM applications by integrating different models, prompts, memory, tools, retrieval systems, and agents.
# The problem without Langchain is that for accessing different APIs you have different codes i.e. the sdk of each company is different .Instead of this , a unified version is there called langchain where you have same code for accessing the apis nevertheless of which company it is . Also it is helpful when a comapny wants to switch from one llm to other , so it doesn't have to change its entire code just change the llm .

# %%
pip install langchain-community
# Out:
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    -------- ------------------------------- 0.5/2.4 MB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.4/2.4 MB 7.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 9.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/557.4 kB ? eta -:--:--
#    ---------------------------------------- 557.4/557.4 kB 8.1 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/671.1 kB ? eta -:--:--
#    --------------------------------------- 671.1/671.1 kB 10.6 MB/s eta 0:00:00
# ...
# Using cached requests-2.34.2-py3-none-any.whl (73 kB)
# ...
#
#   Attempting uninstall: requests
#
#    ------ ---------------------------------  2/12 [requests]
#     Found existing installation: requests 2.32.3
# ...

# %%
pip install langchain-openai
# Out:
# ...
#
# ...

# %%
import os
from langchain_openai import ChatOpenAI

os.environ["OPENAI_API_KEY"]="api-key"

llm=ChatOpenAI(model_name="gpt-3.5-turbo", 
               temperature=0.7 #reproducibility of the output example: 0.0 is deterministic, 1.0 is random
               )
response=llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[6], line 9
#       4 os.environ["OPENAI_API_KEY"]="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"
#       6 llm=ChatOpenAI(model_name="gpt-3.5-turbo",
#       7                temperature=0.7 #reproducibility of the output example: 0.0 is deterministic, 1.0 is random
#       8                )
# ----> 9 response=llm.invoke("What is the capital of France?")
#      10 print(response.content)
#
# File d:\anaconda\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)
#     469     **kwargs: Any,
#     470 ) -> AIMessage:
# ...

# %%
pip install -U langchain-google-genai
# Out:
# ...
#
#    ---------------------------------------- 0/2 [filetype]
#    ---------------------------------------- 0/2 [filetype]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    -------------------- ------------------- 1/2 [langchain-google-genai]
#    ---------------------------------------- 2/2 [langchain-google-genai]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"]="api-key"

llm=ChatGoogleGenerativeAI(model="gemini-2.5-flash",temperature=0.7,)

response=llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**.

# %%
pip install langchain-groq
# Out:
# ...
#
# ...
#
#   Attempting uninstall: groq
#
#     Found existing installation: groq 1.5.0
#
#     Uninstalling groq-1.5.0:
#
#       Successfully uninstalled groq-1.5.0
#
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
#    ---------------------------------------- 0/2 [groq]
# ...

# %%
from langchain_groq import ChatGroq

os.environ["GROQ_API_KEY"]="api key"
llm=ChatGroq(model="llama-3.1-8b-instant",temperature=0.7)
response=llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is Paris.

# %%
pip install langchain-ollama
# Out:
# ...
#   Using cached ollama-0.6.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached ollama-0.6.2-py3-none-any.whl (15 kB)
# ...
#
#    ---------------------------------------- 0/2 [ollama]
#    -------------------- ------------------- 1/2 [langchain-ollama]
#    ---------------------------------------- 2/2 [langchain-ollama]
#
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_ollama import ChatOllama

llm=ChatOllama(model="gemma2:2b",temperature=0.7)
response=llm.invoke("What is the capital of France?")
print(response.content)
# Out:
# The capital of France is **Paris**. 🇫🇷
